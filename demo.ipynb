# %%
""" 
    * Name: Joshua Ludolf & Matthew Trevino
    * Date: 01-29-2025
    * Description: This script demonstrates how to use the NFStreamer class to read a pcap file and print the flows using NFStream.
"""
# Out:
# ' \n    * Name: Joshua Ludolf & Matthew Trevino\n    * Date: 01-29-2025\n    * Description: This script demonstrates how to use the NFStreamer class to read a pcap file and print the flows using NFStream.\n'

# %%
from nfstream import NFStreamer
import os

# %%
def main():
    pcap_file = os.path.join(os.getcwd(), "demo.pcap")

    if not os.path.isfile(pcap_file):
        raise FileNotFoundError(f"The file {pcap_file} does not exist.")

    my_streamer = NFStreamer(source=pcap_file,
                             decode_tunnels=True,
                             bpf_filter=None,
                             promiscuous_mode=True,
                             snapshot_length=1093,
                             idle_timeout=120,
                             active_timeout=1800,
                             accounting_mode=0,
                             udps=None,
                             n_dissections=20,
                             statistical_analysis=False,
                             splt_analysis=0,
                             n_meters=0,
                             max_nflows=0,
                             performance_report=0,
                             system_visibility_mode=0,
                             system_visibility_poll_ms=100)
    

    for flow in my_streamer:
        print(flow) # print the flow

    my_dataframe = my_streamer.to_pandas(columns_to_anonymize=[]) # convert the flows to a pandas dataframe
    print(f"\n{my_dataframe}") # print the dataframe

    total_flows_count = my_streamer.to_csv(path=None, columns_to_anonymize=[], flows_per_file=0, rotate_files=0) # convert the flows to a csv file

# %%
if __name__ == '__main__':
    main()
# Out:
# NFlow(id=0,
#       expiration_id=0,
#       src_ip=71.34.18.237,
#       src_mac=00:0d:93:82:36:3a,
#       src_oui=00:0d:93,
#       src_port=0,
#       dst_ip=148.153.220.84,
#       dst_mac=00:0c:41:82:b2:53,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=67,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891302827,
#       bidirectional_last_seen_ms=1167891302827,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=108,
#       src2dst_first_seen_ms=1167891302827,
#       src2dst_last_seen_ms=1167891302827,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=108,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=1,
#       expiration_id=0,
#       src_ip=196.72.132.179,
#       src_mac=00:0c:41:82:b2:55,
#       src_oui=00:0c:41,
#       src_port=0,
#       dst_ip=62.141.236.37,
#       dst_mac=00:0c:41:82:b2:53,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=235,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891299471,
#       bidirectional_last_seen_ms=1167891299474,
#       bidirectional_duration_ms=3,
#       bidirectional_packets=2,
#       bidirectional_bytes=3152,
#       src2dst_first_seen_ms=1167891299471,
#       src2dst_last_seen_ms=1167891299474,
#       src2dst_duration_ms=3,
#       src2dst_packets=2,
#       src2dst_bytes=3152,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=2,
#       expiration_id=0,
#       src_ip=95.23.88.82,
#       src_mac=00:0c:41:82:b2:55,
#       src_oui=00:0c:41,
#       src_port=0,
#       dst_ip=65.112.32.72,
#       dst_mac=00:0c:41:82:b2:53,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=61,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891322404,
#       bidirectional_last_seen_ms=1167891322404,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=136,
#       src2dst_first_seen_ms=1167891322404,
#       src2dst_last_seen_ms=1167891322404,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=136,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=3,
#       expiration_id=0,
#       src_ip=254.142.107.185,
#       src_mac=00:0c:41:82:b2:55,
#       src_oui=00:0c:41,
#       src_port=0,
#       dst_ip=34.64.127.182,
#       dst_mac=00:0c:41:82:b2:53,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=119,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891291706,
#       bidirectional_last_seen_ms=1167891291706,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=652,
#       src2dst_first_seen_ms=1167891291706,
#       src2dst_last_seen_ms=1167891291706,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=652,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=4,
#       expiration_id=0,
#       src_ip=67.197.56.252,
#       src_mac=00:0d:93:82:36:3a,
#       src_oui=00:0d:93,
#       src_port=0,
#       dst_ip=82.21.187.33,
#       dst_mac=09:00:07:ff:ff:ff,
#       dst_oui=09:00:07,
#       dst_port=0,
#       protocol=199,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891292081,
#       bidirectional_last_seen_ms=1167891292081,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=104,
#       src2dst_first_seen_ms=1167891292081,
#       src2dst_last_seen_ms=1167891292081,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=104,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=5,
#       expiration_id=0,
#       src_ip=147.4.3.34,
#       src_mac=00:0c:41:82:b2:55,
#       src_oui=00:0c:41,
#       src_port=0,
#       dst_ip=151.145.253.164,
#       dst_mac=00:0c:41:82:b2:55,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=30,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891295999,
#       bidirectional_last_seen_ms=1167891295999,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=118,
#       src2dst_first_seen_ms=1167891295999,
#       src2dst_last_seen_ms=1167891295999,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=118,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=6,
#       expiration_id=0,
#       src_ip=191.235.101.72,
#       src_mac=00:0d:93:82:36:3a,
#       src_oui=00:0d:93,
#       src_port=0,
#       dst_ip=235.179.82.46,
#       dst_mac=33:33:00:00:00:02,
#       dst_oui=33:33:00,
#       dst_port=0,
#       protocol=84,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891302136,
#       bidirectional_last_seen_ms=1167891302136,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=132,
#       src2dst_first_seen_ms=1167891302136,
#       src2dst_last_seen_ms=1167891302136,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=132,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
# NFlow(id=7,
#       expiration_id=0,
#       src_ip=129.243.140.209,
#       src_mac=00:0c:41:82:b2:55,
#       src_oui=00:0c:41,
#       src_port=0,
#       dst_ip=24.116.46.234,
#       dst_mac=00:0c:41:82:b2:55,
#       dst_oui=00:0c:41,
#       dst_port=0,
#       protocol=157,
#       ip_version=4,
#       vlan_id=0,
#       tunnel_id=0,
#       bidirectional_first_seen_ms=1167891318018,
#       bidirectional_last_seen_ms=1167891318018,
#       bidirectional_duration_ms=0,
#       bidirectional_packets=1,
#       bidirectional_bytes=118,
#       src2dst_first_seen_ms=1167891318018,
#       src2dst_last_seen_ms=1167891318018,
#       src2dst_duration_ms=0,
#       src2dst_packets=1,
#       src2dst_bytes=118,
#       dst2src_first_seen_ms=0,
#       dst2src_last_seen_ms=0,
#       dst2src_duration_ms=0,
#       dst2src_packets=0,
#       dst2src_bytes=0,
#       application_name=Unknown,
#       application_category_name=Unspecified,
#       application_is_guessed=0,
#       application_confidence=0,
#       requested_server_name=,
#       client_fingerprint=,
#       server_fingerprint=,
#       user_agent=,
#       content_type=)
#
#    id  expiration_id           src_ip            src_mac   src_oui  src_port  \
# 0   0              0     71.34.18.237  00:0d:93:82:36:3a  00:0d:93         0
# 1   1              0   196.72.132.179  00:0c:41:82:b2:55  00:0c:41         0
# 2   2              0      95.23.88.82  00:0c:41:82:b2:55  00:0c:41         0
# 3   3              0  254.142.107.185  00:0c:41:82:b2:55  00:0c:41         0
# 4   4              0    67.197.56.252  00:0d:93:82:36:3a  00:0d:93         0
# 5   5              0       147.4.3.34  00:0c:41:82:b2:55  00:0c:41         0
# 6   6              0   191.235.101.72  00:0d:93:82:36:3a  00:0d:93         0
# 7   7              0  129.243.140.209  00:0c:41:82:b2:55  00:0c:41         0
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  dst2src_bytes  \
# 0   148.153.220.84  00:0c:41:82:b2:53  00:0c:41         0  ...              0
# 1    62.141.236.37  00:0c:41:82:b2:53  00:0c:41         0  ...              0
# 2     65.112.32.72  00:0c:41:82:b2:53  00:0c:41         0  ...              0
# 3    34.64.127.182  00:0c:41:82:b2:53  00:0c:41         0  ...              0
# 4     82.21.187.33  09:00:07:ff:ff:ff  09:00:07         0  ...              0
# 5  151.145.253.164  00:0c:41:82:b2:55  00:0c:41         0  ...              0
# 6    235.179.82.46  33:33:00:00:00:02  33:33:00         0  ...              0
# 7    24.116.46.234  00:0c:41:82:b2:55  00:0c:41         0  ...              0
#
#    application_name  application_category_name  application_is_guessed  \
# 0           Unknown                Unspecified                       0
# 1           Unknown                Unspecified                       0
# 2           Unknown                Unspecified                       0
# 3           Unknown                Unspecified                       0
# 4           Unknown                Unspecified                       0
# 5           Unknown                Unspecified                       0
# 6           Unknown                Unspecified                       0
# 7           Unknown                Unspecified                       0
#
#    application_confidence  requested_server_name  client_fingerprint  \
# 0                       0                    NaN                 NaN
# 1                       0                    NaN                 NaN
# 2                       0                    NaN                 NaN
# 3                       0                    NaN                 NaN
# 4                       0                    NaN                 NaN
# 5                       0                    NaN                 NaN
# 6                       0                    NaN                 NaN
# 7                       0                    NaN                 NaN
#
#    server_fingerprint  user_agent  content_type
# 0                 NaN         NaN           NaN
# 1                 NaN         NaN           NaN
# 2                 NaN         NaN           NaN
# 3                 NaN         NaN           NaN
# 4                 NaN         NaN           NaN
# 5                 NaN         NaN           NaN
# 6                 NaN         NaN           NaN
# 7                 NaN         NaN           NaN
#
# [8 rows x 38 columns]
